# %% [markdown]
# # Day 5 — Practice Session
# ### Dictionaries · Python for Data Science
#
# **Prepared by Srinivasa Sai Chava**  ·  Boston University
#
# ---
#
# **Time: 30 minutes** · Attempt everything yourself first.
#
# | Part | Focus | Questions | Suggested time |
# |---|---|---|---|
# | A | Predict the output (no running!) | 8 | 8 min |
# | B | Spot & fix the bug | 4 | 7 min |
# | C | Write the code | 5 | 12 min |
# | D | Challenge | 2 | 3 min / homework |
#
# **Ask yourself on every lookup:** *could this key be missing?* If yes, use `.get()`.
#
# > Most of today's errors are one word long: `KeyError`.

# %% [markdown]
# ---
# # Part A — Predict the Output  *(8 min)*

# %% [markdown]
# ### A1. What prints on each line?

# %%
marks = {"Python": 88, "Stats": 71}

print(marks["Python"])
print(marks.get("ML"))
print(marks.get("ML", 0))

# %% [markdown]
# *Your prediction:*

# %% [markdown]
# ### A2. What is `d` at the end?

# %%
d = {"a": 1}
d["b"] = 2
d["a"] = 99

print(d)
print(len(d))
# Out:
# {'a': 99, 'b': 2}
# 2

# %% [markdown]
# *Your prediction:*

# %% [markdown]
# ### A3. True or False for each?

# %%
marks = {"Python": 88, "Stats": 71}

print("Python" in marks)
print(88 in marks)
print(88 in marks.values())

# %% [markdown]
# *Your prediction:*

# %% [markdown]
# ### A4. What does the loop print?

# %%
marks = {"Python": 88, "Stats": 71}

for x in marks:
    print(x)

# %% [markdown]
# *Your prediction:*

# %% [markdown]
# ### A5. What is `counts` at the end?

# %%
words = ["a", "b", "a"]

counts = {}
for w in words:
    counts[w] = counts.get(w, 0) + 1

print(counts)

# %% [markdown]
# *Your prediction:*

# %% [markdown]
# ### A6. What does this produce?

# %%
records = [("maths", "Ravi"), ("cs", "Sara"), ("maths", "Amit")]

groups = {}
for subject, name in records:
    groups.setdefault(subject, []).append(name)

print(groups)

# %% [markdown]
# *Your prediction:*

# %% [markdown]
# ### A7. Which of these are legal?

# %%
a = {"name": 1}
b = {42: 1}
c = {(3, 7): 1}
d = {[1, 2]: 1}

# %% [markdown]
# *Your prediction:*

# %% [markdown]
# ### A8. What does the merge give?

# %%
defaults = {"colour": "blue", "size": 10}
user     = {"size": 14}

print(defaults | user)
print(user | defaults)

# %% [markdown]
# *Your prediction:*

# %% [markdown]
# ---
# # Part B — Spot & Fix the Bug  *(7 min)*

# %% [markdown]
# ### B1. This crashes on the third student.

# %%
marks = {"ravi": 88, "sara": 91}

for name in ["ravi", "sara", "amit"]:
    print(name, marks[name])

# %% [markdown]
# *Error:*
#
# *Your fix:*

# %% [markdown]
# ### B2. This should count the words. It doesn't.

# %%
words = ["a", "b", "a"]

counts = {}
for w in words:
    counts[w] = counts[w] + 1

print(counts)

# %% [markdown]
# *Error:*
#
# *Your fix:*

# %% [markdown]
# ### B3. This should delete the high scores.

# %%
marks = {"a": 30, "b": 80, "c": 90}

for k in marks:
    if marks[k] > 50:
        del marks[k]

print(marks)

# %% [markdown]
# *Error:*
#
# *Your fix:*

# %% [markdown]
# ### B4. This should print Neha's age.

# %%
students = {"ravi": {"age": 23}, "sara": {"age": 22}}

print(students["neha"]["age"])

# %% [markdown]
# *Error:*
#
# *Your fix:*

# %% [markdown]
# ---
# # Part C — Write the Code  *(12 min)*

# %% [markdown]
# ### C1. Count the letters
# Count how many times each letter appears in `"dictionary"`.
# Ignore nothing — count every character.
#
# Expected: `{'d': 1, 'i': 2, 'c': 1, 't': 1, 'o': 1, 'n': 1, 'a': 1, 'r': 1, 'y': 1}`
# (only `i` repeats)

# %%
word = "dictionary"

# your code here

# %% [markdown]
# ### C2. Group students by grade
# Given the marks below, build a dictionary mapping each **grade** to the **list of students**
# who got it.
#
# - A: 75+ · B: 60–74 · C: 40–59 · F: below 40

# %%
marks = {"ravi": 88, "sara": 71, "amit": 35, "priya": 64, "neha": 92}

# your code here

# %% [markdown]
# ### C3. Invert a dictionary
# Turn `{"a": 1, "b": 2, "c": 3}` into `{1: "a", 2: "b", 3: "c"}` — values become keys.

# %%
d = {"a": 1, "b": 2, "c": 3}

# your code here

# %% [markdown]
# ### C4. Filter a dictionary
# From the marks below, build a new dictionary containing only the students who passed (40+).
# Leave the original untouched.

# %%
marks = {"ravi": 88, "sara": 35, "amit": 64, "priya": 22}

# your code here

# %% [markdown]
# ### C5. Merge with defaults
# A program has default settings and a user's overrides. Produce the final settings,
# with the user's choices winning, without changing either original dictionary.

# %%
defaults = {"colour": "blue", "size": 10, "debug": False}
user     = {"size": 14, "debug": True}

# your code here

# %% [markdown]
# ---
# # Part D — Challenge  *(3 min, or take home)*

# %% [markdown]
# ### D1. Safe nested lookup
# Write `deep_get(data, *keys)` that walks a nested dictionary and returns `None`
# instead of raising if any level is missing.
#
# `deep_get(data, "ravi", "address", "city")` should work, and also not crash when
# `"ravi"` or `"address"` is absent.

# %%
data = {
    "ravi": {"address": {"city": "Pune"}},
    "sara": {"age": 22},
}

# your code here

# %% [markdown]
# ### D2. Word frequency report
# Given the sentence below, print the **three most common words**, highest first,
# in the format `word: count`.
#
# Ignore case, and strip the full stops.

# %%
text = "the cat sat on the mat. the cat was happy. the mat was flat."

# your code here

# %% [markdown]
# ---
# ## Done? Self-check
#
# - [ ] I know the difference between `d[key]` and `d.get(key)`
# - [ ] I know why `88 in marks` is `False` when 88 is a value
# - [ ] I can write the counting pattern from memory
# - [ ] I can explain what `setdefault(k, [])` returns and why `.append()` works after it
# - [ ] I know why a list cannot be a dictionary key
# - [ ] I know which side wins when two dictionaries are merged
# - [ ] I know why deleting inside a `for k in d:` loop fails
#
# ### Homework
# 1. Count how many times each letter appears in a sentence.
# 2. Invert a dictionary so the values become keys — handle duplicate values sensibly.
# 3. Extend the gradebook with a `top_student()` function returning the highest average.
#
# ### Next class — Topic 1.6: Comprehensions
# One-line list, dict and set comprehensions, with conditions.
#
# ---
# *Slides & notebooks by Srinivasa Sai Chava · Boston University*
