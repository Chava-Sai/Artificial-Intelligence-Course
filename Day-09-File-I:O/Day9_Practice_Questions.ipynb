# %% [markdown]
# # Day 9 — Practice Session
# ### File I/O · Python for Data Science
#
# **Prepared by Srinivasa Sai Chava**  ·  Boston University
#
# ---
#
# **Time: 30 minutes** · Attempt everything yourself first.
#
# | Part | Focus | Questions | Suggested time |
# |---|---|---|---|
# | A | Predict the output (no running!) | 8 | 8 min |
# | B | Spot & fix the bug | 4 | 7 min |
# | C | Write the code | 5 | 12 min |
# | D | Challenge | 2 | 3 min / homework |
#
# > **Run the setup cell first.** This notebook creates its own sample files — nothing of
# > yours is at risk.
# >
# > Before every `open()`, say the mode out loud. `"w"` means **erase**.

# %% [markdown]
# ---
# ## Setup — run this first
#
# Creates the sample files every question below uses.

# %%
import csv

with open("names.txt", "w", encoding="utf-8") as f:
    f.write("Ravi\n")
    f.write("Sara\n")
    f.write("Amit")                # no newline on the last line

with open("marks.csv", "w", newline="", encoding="utf-8") as f:
    w = csv.writer(f)
    w.writerow(["name", "city", "subject", "mark"])
    w.writerows([
        ["Ravi", "Pune",       "python", 88],
        ["Sara", "Mumbai, MH", "python", 91],
        ["Ravi", "Pune",       "stats",  71],
        ["Amit", "Delhi",      "stats",  35],
    ])

print("Sample files ready.")
print(open("marks.csv", encoding="utf-8").read())

# %% [markdown]
# ---
# # Part A — Predict the Output  *(8 min)*

# %% [markdown]
# ### A1. What is printed?

# %%
with open("names.txt", encoding="utf-8") as f:
    print(repr(f.read()))

# %% [markdown]
# *Your prediction:*

# %% [markdown]
# ### A2. Which comparisons are True?

# %%
with open("names.txt", encoding="utf-8") as f:
    for line in f:
        print(repr(line), line == "Ravi", line.strip() == "Ravi")

# %% [markdown]
# *Your prediction:*

# %% [markdown]
# ### A3. What does the file contain afterwards?

# %%
with open("demo.txt", "w", encoding="utf-8") as f:
    f.write("Ravi")
    f.write("Sara")

print(repr(open("demo.txt", encoding="utf-8").read()))

# %% [markdown]
# *Your prediction:*

# %% [markdown]
# ### A4. What does the file contain now?

# %%
with open("demo.txt", "w", encoding="utf-8") as f:
    f.write("first\n")

with open("demo.txt", "w", encoding="utf-8") as f:
    f.write("second\n")

print(repr(open("demo.txt", encoding="utf-8").read()))

# %% [markdown]
# *Your prediction:*

# %% [markdown]
# ### A5. What does the second read give?

# %%
with open("names.txt", encoding="utf-8") as f:
    first  = f.read()
    second = f.read()

print(len(first), repr(second))

# %% [markdown]
# *Your prediction:*

# %% [markdown]
# ### A6. How many fields does each row have?

# %%
with open("marks.csv", encoding="utf-8") as f:
    next(f)                              # skip the header
    for line in f:
        print(len(line.strip().split(",")), line.strip().split(","))

# %% [markdown]
# *Your prediction:*

# %% [markdown]
# ### A7. Same file, using the csv module. What changes?

# %%
import csv

with open("marks.csv", newline="", encoding="utf-8") as f:
    reader = csv.reader(f)
    next(reader)
    for row in reader:
        print(len(row), row)

# %% [markdown]
# *Your prediction:*

# %% [markdown]
# ### A8. What type is `row`, and what does it print?

# %%
import csv

with open("marks.csv", newline="", encoding="utf-8") as f:
    row = next(csv.DictReader(f))

print(type(row).__name__)
print(row["name"], row["mark"])

# %% [markdown]
# *Your prediction:*

# %% [markdown]
# ---
# # Part B — Spot & Fix the Bug  *(7 min)*

# %% [markdown]
# ### B1. This should READ the file. What does it actually do?

# %%
# First, put something in the file
with open("important.txt", "w", encoding="utf-8") as f:
    f.write("valuable data\n")

# Now "read" it
with open("important.txt", "w", encoding="utf-8") as f:
    content = f.read()

print(repr(open("important.txt", encoding="utf-8").read()))

# %% [markdown]
# *What's wrong:*
#
# *Your fix:*

# %% [markdown]
# ### B2. Why does nothing match?

# %%
with open("names.txt", encoding="utf-8") as f:
    for line in f:
        if line == "Sara":
            print("Found Sara")
print("done")

# %% [markdown]
# *What's wrong:*
#
# *Your fix:*

# %% [markdown]
# ### B3. This should total the marks.

# %%
import csv

total = 0
with open("marks.csv", newline="", encoding="utf-8") as f:
    for row in csv.DictReader(f):
        total += row["mark"]

print(total)

# %% [markdown]
# *Error:*
#
# *Your fix:*

# %% [markdown]
# ### B4. This crashes if the file is missing.

# %%
with open("no_such_file.csv", encoding="utf-8") as f:
    rows = f.readlines()

print("loaded", len(rows), "rows")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 with open("no_such_file.csv", encoding="utf-8") as f:
#       2     rows = f.readlines()
#       4 print("loaded", len(rows), "rows")
#
# File ~/Library/Python/3.9/lib/python/site-packages/IPython/core/interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'no_such_file.csv'

# %% [markdown]
# *Error:*
#
# *Your fix:*

# %% [markdown]
# ---
# # Part C — Write the Code  *(12 min)*

# %% [markdown]
# ### C1. Count the lines
# Write a function `count_lines(path)` that returns how many lines a file has.
# Test it on `names.txt`.

# %%
# your code here

# %% [markdown]
# ### C2. Write a list to a file
# Write `save_names(names, path)` that writes each name on its own line.
# Then read it back and print it to prove it worked.

# %%
names = ["Ravi", "Sara", "Amit", "Priya"]

new_names = []

for i in range(len(names)-1,-1,-1):
    new_names.append(names[i])

print(new_names)

# your code here
# Out:
# ['Priya', 'Amit', 'Sara', 'Ravi']

# %% [markdown]
# ### C3. Filter a CSV into a new file
# Read `marks.csv` and write **only the rows where the mark is 40 or more** into a new file
# called `passed.csv`, keeping the header.
#
# Use `DictReader` and `DictWriter`.

# %%
# your code here

# %% [markdown]
# ### C4. Append to a log
# Write `log(message, path="app.log")` that appends a message on its own line.
# Call it three times and print the file.

# %%
# your code here

# %% [markdown]
# ### C5. Read, process, write
# Read `marks.csv`, compute each **student's** average mark, and write a new CSV
# `averages.csv` with columns `name` and `average` (one decimal place).

# %%
# your code here

# %% [markdown]
# ---
# # Part D — Challenge  *(3 min, or take home)*

# %% [markdown]
# ### D1. Word frequency from a file
# Write the text below to `essay.txt`, then read it back and print the **three most common
# words**, ignoring case and full stops.
#
# Combine today's file reading with Day 5's counting pattern.

# %%
text = "the cat sat on the mat. the cat was happy. the mat was flat."

# your code here

# %% [markdown]
# ### D2. Merge two CSV files
# Create a second file `cities.csv` mapping each city to a state, then produce
# `merged.csv` containing every row of `marks.csv` with a `state` column added.

# %%
# your code here

# %% [markdown]
# ---
# ## Done? Self-check
#
# - [ ] I know why `with` is better than calling `close()` myself
# - [ ] I can name what `"w"` does to an existing file
# - [ ] I know why `line == "Ravi"` fails when reading a file
# - [ ] I know that `write()` does not add a newline
# - [ ] I can say why `split(",")` is not safe on a CSV
# - [ ] I know every CSV value arrives as a string
# - [ ] I know why CSVs are opened with `newline=""`
#
# ### Homework
# 1. Write a word-frequency counter that reads a text file.
# 2. Read a CSV and write out only the rows that pass a filter.
# 3. Add `try`/`except` to every file function you have written.
#
# ### Next class — Topic 1.10: Exception Handling & Modules
# `try` / `except` / `finally`, raising and writing your own exceptions, importing modules
# and packages.
#
# ---
# *Slides & notebooks by Srinivasa Sai Chava · Boston University*
