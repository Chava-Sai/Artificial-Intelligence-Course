# %% [markdown]
# # Day 4 — Practice Session### Lists, Tuples & Sets · Python for Data Science**Prepared by Srinivasa Sai Chava**  ·  Boston University---**Time: 30 minutes** · Attempt everything yourself first.| Part | Focus | Questions | Suggested time ||---|---|---|---|| A | Predict the output (no running!) | 8 | 8 min || B | Spot & fix the bug | 4 | 7 min || C | Write the code | 5 | 12 min || D | Challenge | 2 | 3 min / homework |**Ask yourself on every line:** *does this change the original, or give me a new one?*> If a variable mysteriously becomes `None`, you assigned the result of an in-place method.> That is today's single most likely bug.

# %% [markdown]
# ---# Part A — Predict the Output  *(8 min)*Write your prediction in the markdown cell, then run and compare.

# %% [markdown]
# ### A1. What does each slice give?

# %%
marks = [88, 71, 64, 90, 55]print(marks[1:4])print(marks[:2])print(marks[-1])print(marks[::-1])

# %% [markdown]
# *Your prediction:*

# %% [markdown]
# ### A2. What is `nums` after each line?

# %%
nums = [1, 2]nums.append([3, 4])print(nums)nums = [1, 2]nums.extend([3, 4])print(nums)

# %% [markdown]
# *Your prediction:*

# %% [markdown]
# ### A3. What prints?

# %%
nums = [3, 1, 2]result = nums.sort()print(result)print(nums)

# %% [markdown]
# *Your prediction:*

# %% [markdown]
# ### A4. Does the original change?

# %%
nums = [3, 1, 2]result = sorted(nums)print(result)print(nums)

# %% [markdown]
# *Your prediction:*

# %% [markdown]
# ### A5. What is `a` at the end?

# %%
a = [1, 2, 3]b = ab.append(4)print(a)print(a is b)

# %% [markdown]
# *Your prediction:*

# %% [markdown]
# ### A6. What happens on each line?

# %%
point = (3, 7)print(point[0])point[0] = 9

# %% [markdown]
# *Your prediction:*

# %% [markdown]
# ### A7. What is the type of each?

# %%
a = (5)b = (5,)c = {}d = set()print(type(a).__name__, type(b).__name__, type(c).__name__, type(d).__name__)

# %% [markdown]
# *Your prediction:*

# %% [markdown]
# ### A8. What does each print?

# %%
s = {3, 1, 2, 3, 1}print(s)print(len(s))a = {1, 2, 3}b = {3, 4, 5}print(a & b)print(a - b)

# %% [markdown]
# *Your prediction:*

# %% [markdown]
# ---# Part B — Spot & Fix the Bug  *(7 min)*Each cell is **broken**. Predict the problem, run it to confirm, then fix it.

# %% [markdown]
# ### B1. This should end with four items. Instead something is very wrong.

# %%
nums = [1, 2, 3]nums = nums.append(4)print(nums)

# %% [markdown]
# *What's wrong:* *Your fix:*

# %% [markdown]
# ### B2. This should print the sorted list.

# %%
nums = [3, 1, 2]nums = nums.sort()print(nums)

# %% [markdown]
# *What's wrong:* *Your fix:*

# %% [markdown]
# ### B3. `original` should be untouched. It isn't.

# %%
original = [1, 2, 3]backup = originalbackup.append(99)print("original:", original)print("backup  :", backup)

# %% [markdown]
# *What's wrong:* *Your fix:*

# %% [markdown]
# ### B4. Two problems here. Find both.

# %%
unique_names = {}unique_names.add("Ravi")print(unique_names[0])

# %% [markdown]
# *What's wrong:* *Your fix:*

# %% [markdown]
# ---# Part C — Write the Code  *(12 min)*

# %% [markdown]
# ### C1. Slicing practiceGiven the list below, print each of these using **slicing only**:1. the first three items2. the last two items3. every second item4. the list reversed

# %%
marks = [88, 71, 64, 90, 55, 42, 77]# your code here

# %% [markdown]
# ### C2. Remove duplicates, keep the orderWrite `remove_duplicates(items)` that removes duplicates **without changing the order**.`["b", "a", "b", "c", "a"]` should give `["b", "a", "c"]`.(`list(set(items))` will not do — it loses the order.)

# %%
names = ["b", "a", "b", "c", "a"]# your code here

# %% [markdown]
# ### C3. Top three scoresGiven the marks below, print the **three highest** scores, largest first —without changing the original list.

# %%
marks = [45, 78, 33, 90, 62, 88, 55]# your code here

# %% [markdown]
# ### C4. Comparing two class listsGiven the two sets below, print:1. students in **both** sections2. **all** students across both3. students only in section A4. students in exactly **one** section

# %%
section_a = {"ravi", "sara", "amit", "priya"}section_b = {"sara", "priya", "neha"}# your code here

# %% [markdown]
# ### C5. Flatten a nested listTurn `[[1, 2], [3, 4], [5]]` into `[1, 2, 3, 4, 5]` using a loop.

# %%
nested = [[1, 2], [3, 4], [5]]# your code here

# %% [markdown]
# ---# Part D — Challenge  *(3 min, or take home)*

# %% [markdown]
# ### D1. Rotate a listWrite `rotate(items, n)` that moves the first `n` items to the end.`rotate([1,2,3,4,5], 2)` should give `[3, 4, 5, 1, 2]`.Use slicing — no loop needed.

# %%
# your code here

# %% [markdown]
# ### D2. Second largestWrite `second_largest(nums)` that returns the second largest **distinct** value.`[10, 5, 10, 3]` should give `5`, not `10` — the two 10s count once.Return `None` if there is no second distinct value.

# %%
# your code here

# %% [markdown]
# ---## Done? Self-check- [ ] I know why `marks[1:4]` gives three items, not four- [ ] I can explain the difference between `append` and `extend`- [ ] I know why `nums = nums.sort()` destroys my list- [ ] I can explain the difference between `sort()` and `sorted()`- [ ] I know why `b = a` is not a copy, and three ways to make one- [ ] I know why `(5)` is not a tuple and `{}` is not a set- [ ] I can use `&`, `|`, `-` and `^` on two sets### Homework1. Write `remove_duplicates(items)` keeping order (extend C2 to handle any type).2. Given two lists, print the items in both, in either, and in only one.3. Rotate a list by `n` positions using slicing.### Next class — Topic 1.5: DictionariesKey-value pairs, nested dictionaries, dictionary methods, and iterating over them.---*Slides & notebooks by Srinivasa Sai Chava · Boston University*
