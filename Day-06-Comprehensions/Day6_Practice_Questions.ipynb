# %% [markdown]
# # Day 6 — Practice Session
# ### Comprehensions · Python for Data Science
#
# **Prepared by Srinivasa Sai Chava**  ·  Boston University
#
# ---
#
# **Time: 30 minutes** · Attempt everything yourself first.
#
# | Part | Focus | Questions | Suggested time |
# |---|---|---|---|
# | A | Predict the output (no running!) | 8 | 8 min |
# | B | Spot & fix the bug | 4 | 7 min |
# | C | Write the code | 5 | 12 min |
# | D | Challenge | 2 | 3 min / homework |
#
# **Stuck?** Write the loop first, then move the pieces. That is not a step backwards —
# it is how experienced people write the tricky ones too.
#
# > `if` at the **end** drops items. `if`/`else` at the **front** changes items.

# %% [markdown]
# ---
# # Part A — Predict the Output  *(8 min)*

# %% [markdown]
# ### A1. What does this build?

# %%
nums = [1, 2, 3, 4]
print([n * 2 for n in nums])

# %% [markdown]
# *Your prediction:*

# %% [markdown]
# ### A2. What is the result — and its type?

# %%
words = ["python", "is", "great"]
print([len(w) for w in words])
print({len(w) for w in words})

# %% [markdown]
# *Your prediction:*

# %% [markdown]
# ### A3. How many items come out?

# %%
nums = [3, -1, 4, -5, 2]
print([n for n in nums if n > 0])

# %% [markdown]
# *Your prediction:*

# %% [markdown]
# ### A4. Same data. How many items now?

# %%
nums = [3, -1, 4, -5, 2]
print(["pos" if n > 0 else "neg" for n in nums])

# %% [markdown]
# *Your prediction:*

# %% [markdown]
# ### A5. What does this produce?

# %%
d = {"a": 1, "b": 2, "c": 3}
print({k: v * 10 for k, v in d.items() if v > 1})

# %% [markdown]
# *Your prediction:*

# %% [markdown]
# ### A6. What is `flat`?

# %%
matrix = [[1, 2], [3, 4], [5, 6]]
flat = [n for row in matrix for n in row]
print(flat)

# %% [markdown]
# *Your prediction:*

# %% [markdown]
# ### A7. What prints — both lines?

# %%
g = (n for n in [1, 2, 3])
print(sum(g))
g = (n for n in [1, 2, 3])
print(sum(g))
# Out:
# 6
# 6
# 0
# 0

# %% [markdown]
# *Your prediction:*

# %% [markdown]
# ### A8. What is `result`, and what is printed?

# %%
nums = 123
n = print(nums + 2)
print(n)
# Out:
# 125
# None

# %%
nums = [1, 2, 3]
result = [print(n) for n in nums]
print("result:", result)
# Out:
# result: [1, 2, 3]

# %%
n

# %% [markdown]
# *Your prediction:*

# %% [markdown]
# ---
# # Part B — Spot & Fix the Bug  *(7 min)*

# %% [markdown]
# ### B1. This should keep only the positives.

# %%
nums = [3, -1, 4, -5]
print([n if n > 0 for n in nums])

# %% [markdown]
# *Error:*
#
# *Your fix:*

# %% [markdown]
# ### B2. This should replace negatives with zero.

# %%
nums = [3, -1, 4, -5]
print([n for n in nums if n > 0 else 0])

# %% [markdown]
# *Error:*
#
# *Your fix:*

# %% [markdown]
# ### B3. This should give a tuple of squares.

# %%
nums = [1, 2, 3]
squares = (n * n for n in nums)

print(squares)
print(squares[0])

# %% [markdown]
# *Error:*
#
# *Your fix:*

# %% [markdown]
# ### B4. This should print each name. Something extra happens.

# %%
names = ["Ravi", "Sara"]
output = [print(n) for n in names]
print(output)

# %% [markdown]
# *What's wrong:*
#
# *Your fix:*

# %% [markdown]
# ---
# # Part C — Write the Code  *(12 min)*
#
# Write the loop first if it helps, then convert it.

# %% [markdown]
# ### C1. Convert this loop
# Rewrite the loop below as a single comprehension.

# %%
words = ["python", "is", "really", "great"]

lengths = []
for w in words:
    lengths.append(len(w))
print(lengths)

# your comprehension here

# %% [markdown]
# ### C2. Filter and transform at once
# From the list below, produce a list of the **uppercase** names that are
# longer than three characters.

# %%
names = ["ravi", "jo", "sara", "al", "priya"]

# your code here

# %% [markdown]
# ### C3. Grade every mark
# Turn the marks below into a list of grades — `"pass"` for 40 or more, `"fail"` otherwise.
# The result must have the **same number of items** as the input.

# %%
marks = [88, 35, 71, 22, 64]

# your code here

# %% [markdown]
# ### C4. Invert a dictionary
# Swap the keys and values of the dictionary below, in one line.

# %%
codes = {"in": "India", "us": "USA", "uk": "Britain"}

# your code here

# %% [markdown]
# ### C5. Clean a messy list
# From the raw list below, produce a clean list of names: stripped of spaces,
# title-cased, with the blanks removed.

# %%
raw = ["  ravi ", "SARA", "", "  ", "amit  "]

# your code here

# %% [markdown]
# ---
# # Part D — Challenge  *(3 min, or take home)*

# %% [markdown]
# ### D1. Word length dictionary
# From the sentence below, build a dictionary mapping each **unique** word to its length.
# Ignore case, and drop the full stops.

# %%
text = "The cat sat on the mat. The mat was flat."

# your code here

# %% [markdown]
# ### D2. Transpose a matrix
# Turn rows into columns:
#
# `[[1, 2, 3], [4, 5, 6]]`  →  `[[1, 4], [2, 5], [3, 6]]`
#
# Do it with a nested comprehension. (Then check your answer against `zip`.)

# %%
matrix = [[1, 2, 3], [4, 5, 6],[7,8,9]]

transposed_matrix = list(zip(*matrix))

print(transposed_matrix)

#-------------------------------------

transposed = []

for i in zip(*matrix):
    transposed.append(list(i))

print(transposed)

#-------------------------------------

transposed = [[row[col] for row in matrix] for col in range(len(matrix[0]))]

print(transposed)
# Out:
# [(1, 4, 7), (2, 5, 8), (3, 6, 9)]
# [[1, 4, 7], [2, 5, 8], [3, 6, 9]]

# %% [markdown]
# ---
# ## Done? Self-check
#
# - [ ] I can turn any simple build-a-list loop into a comprehension
# - [ ] I know why `if` at the end can make the result shorter
# - [ ] I know why `if`/`else` at the front never changes the length
# - [ ] I know why a bare `if` at the front is a `SyntaxError`
# - [ ] I know what the colon does in `{k: v for ...}`
# - [ ] I know that `(x for x in y)` is a generator, not a tuple
# - [ ] I can say when a plain loop is the better choice
#
# ### Homework
# 1. Rewrite three loops from Days 2–5 as comprehensions.
# 2. Build `{word: length}` for every word in a sentence.
# 3. Find one comprehension that is **worse** than its loop, and explain why.
#
# ### Next class — Topic 1.7: Classes & Objects
# Defining a class, `__init__`, attributes, methods, and creating objects.
#
# ---
# *Slides & notebooks by Srinivasa Sai Chava · Boston University*
